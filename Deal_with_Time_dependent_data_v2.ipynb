# %% [markdown]
# # Time-Dependent S21 Measurement
#
# This notebook performs the following steps:
# 1. **Organize & Rename** raw sweep CSV files -> 3-column CSV files
# 2. **Trim** visually identify the stable onset and discard early sweeps
# 3. **Fit** each sweep with the DCM circle fit to extract Q, Qi, Qc, fc
# 4. **PSD analysis** of the fit parameters using Welch's method

# %% [markdown]
# ## Section 0 — Imports & Path Setup

# %%
import sys
import re
import shutil
from pathlib import Path
from datetime import datetime
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal as sig

matplotlib.rcParams['figure.dpi'] = 100

# Point this to the local clone of Fitting_Code_Lab_2.0 
FITTING_CODE_DIR = Path(r"C:\Users\user\Documents\GitHub\Fitting_Code_Lab_2.0")

sys.path.insert(0, str(FITTING_CODE_DIR / "helper_scripts"))
sys.path.insert(0, str(FITTING_CODE_DIR / "scresonators"))

import helper_fit as hf

print("All imports successful.")
# Out:
# helper_fit loaded from: C:\Users\user\Documents\GitHub\Fitting_Code_Lab_2.0\helper_scripts\helper_fit.py
# helper_misc loaded from: C:\Users\user\Documents\GitHub\Fitting_Code_Lab_2.0\helper_scripts\helper_misc.py
# fit_resonator.resonator loaded from: C:\Users\user\Documents\GitHub\Fitting_Code_Lab_2.0\scresonators\fit_resonator\resonator.py
# fit_resonator.fit loaded from: C:\Users\user\Documents\GitHub\Fitting_Code_Lab_2.0\scresonators\fit_resonator\fit.py
# All imports successful.

# %% [markdown]
# ## Section 1 — Organize & Rename Measured Files
#
# **Input** a flat source directory containing several csv and png VNA sweeps, e.g.:
# 1. 20260522_043019_sweep0978_5p607840GHz_-20p0dBm_200avgs_201points.csv
# 2. 20260522_042934_sweep0977_5p607840GHz_-20p0dBm_200avgs_201points.png
#
# **Output** organized folder `{target_dir}/{res_label}_{freq_str}/` with renamed 3-column headerless CSVs:
# 1. QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_0.csv
# 2. QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_1.csv
# 3. ...
# 4. metadata.csv (timing & indexing record)
#
# [Note] Col0=freq(Hz), Col1=|S21|(dB), Col2=phase(deg)

# %%
# User Configuration
source_dir  = Path(r"C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21\05_21_162111")       # <-- flat folder with all sweeps
target_dir  = Path(r"C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized")   # <-- output root

sample_name  = "QSD_CPW_w6g3_03"   # used in every output filename
temperature  = "15mK"              # used in every output filename
res_label    = "Resonator_2"       # used for the output subfolder name
# ─────────────────────────────────────────────────────────────────────────────

if not source_dir.exists():
    raise FileNotFoundError(f"Source directory not found: {source_dir}")

print(f"Source dir  : {source_dir}")
print(f"Target dir  : {target_dir}")
print(f"Sample name : {sample_name}")
print(f"Temperature : {temperature}")
print(f"Resonator   : {res_label}")
# Out:
# Source dir  : C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21\05_21_162111
# Target dir  : C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized
# Sample name : QSD_CPW_w6g3_03
# Temperature : 15mK
# Resonator   : Resonator_2

# %%
# Helper functions for parsing sweep folder names

_FOLDER_RE = re.compile(
    r'^(\d{8}_\d{6})_sweep(\d+)_([\dp]+GHz)_([-\dp]+dBm)_(\d+)avgs_(\d+)points$'
)

def parse_sweep_folder(folder_name: str) -> dict | None:
    """Parse a raw sweep folder name. Returns None if the name does not match."""
    m = _FOLDER_RE.match(folder_name)
    if not m:
        return None
    ts, sw_idx, freq_raw, pwr_raw, avgs, points = m.groups()
    return {
        'timestamp_str' : ts,
        'sweep_idx'     : int(sw_idx),
        'freq_str_raw'  : freq_raw,
        'power_str_raw' : pwr_raw,
        'avgs'          : int(avgs),
        'points'        : int(points),
    }

def freq_raw_to_rounded(freq_str_raw: str, n_decimals: int = 3) -> str:
    """'5p607840GHz' → '5p608GHz'  (rounded to n_decimals decimal places)."""
    val = float(freq_str_raw.replace('GHz', '').replace('p', '.'))
    return f"{round(val, n_decimals):.{n_decimals}f}".replace('.', 'p') + "GHz"

def power_raw_to_clean(power_str_raw: str) -> str:
    """'-20p0dBm' → '-20dBm';  '-20p5dBm' → '-20.5dBm'."""
    val = float(power_str_raw.replace('dBm', '').replace('p', '.'))
    return f"{int(val)}dBm" if val == int(val) else f"{val}dBm"

def timestamp_to_unix(ts: str) -> float:
    """'20260522_043019' → Unix timestamp (float seconds)."""
    return datetime.strptime(ts, "%Y%m%d_%H%M%S").timestamp()

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# Scan all CSV files in the flat source directory

sweep_entries = []
skipped = []

for csv_path in sorted(source_dir.glob("*.csv")):
    info = parse_sweep_folder(csv_path.stem)   # stem = filename without .csv
    if info is None:
        skipped.append(csv_path.name)
        continue

    info['csv_path']  = csv_path
    info['unix_time'] = timestamp_to_unix(info['timestamp_str'])
    info['freq_str']  = freq_raw_to_rounded(info['freq_str_raw'])
    info['power_str'] = power_raw_to_clean(info['power_str_raw'])
    sweep_entries.append(info)

if skipped:
    print(f"[INFO] Skipped {len(skipped)} non-matching CSV files.")

print(f"\nValid sweep CSVs found: {len(sweep_entries)}")

# ── Verify a single center frequency ─────────────────────────────────────────
all_freq_strs = set(e['freq_str'] for e in sweep_entries)
if len(all_freq_strs) != 1:
    print(f"[WARNING] Multiple rounded frequencies found: {all_freq_strs}")
    print("  This script is designed for one resonator (one center frequency).")
    print("  Proceeding with the most common one...")
    from collections import Counter
    freq_str = Counter(e['freq_str'] for e in sweep_entries).most_common(1)[0][0]
    sweep_entries = [e for e in sweep_entries if e['freq_str'] == freq_str]
else:
    freq_str = all_freq_strs.pop()
print(f"Center frequency (rounded): {freq_str}")

# ── Group by power, sort each group by sweep_idx ─────────────────────────────
power_groups = defaultdict(list)
for e in sweep_entries:
    power_groups[e['power_str']].append(e)

all_powers = sorted(power_groups.keys(), key=lambda p: float(p.replace('dBm', '')))

print(f"\nPowers found: {all_powers}")
for pwr in all_powers:
    g = sorted(power_groups[pwr], key=lambda e: e['sweep_idx'])
    power_groups[pwr] = g   # store sorted
    print(f"  {pwr:>10s} : {len(g):>5d} sweeps  "
          f"(sweep {g[0]['sweep_idx']:04d} → {g[-1]['sweep_idx']:04d})")
# Out:
# [INFO] Skipped 1 non-matching CSV files.
#
# Valid sweep CSVs found: 1000
# Center frequency (rounded): 5p608GHz
#
# Powers found: ['-80dBm', '-60dBm', '-40dBm', '-20dBm']
#       -80dBm :   250 sweeps  (sweep 0004 → 1000)
#       -60dBm :   250 sweeps  (sweep 0003 → 0999)
#       -40dBm :   250 sweeps  (sweep 0002 → 0998)
#       -20dBm :   250 sweeps  (sweep 0001 → 0997)

# %%
# Write organized 3-column headerless CSVs
#
# Raw CSV columns  (with header):
#   0=freq(Hz), 1=|S21|(dB), 2=phase(rad), 3=sweep_idx, 4=timestamp_start,
#   5=elapsed_s, 6=f_center, 7=f_span, 8=power_dBm, 9=if_bw, 10=averages
#
# Organized CSV columns (no header):
#   0=freq(Hz), 1=|S21|(dB), 2=phase(deg)   

organized_dir = target_dir / f"{res_label}_{freq_str}"
organized_dir.mkdir(parents=True, exist_ok=True)

metadata_rows = []

for pwr in all_powers:
    for file_idx, entry in enumerate(power_groups[pwr]):
        # Read raw CSV
        raw_df = pd.read_csv(entry['csv_path'])
        freq_hz   = raw_df.iloc[:, 0].values
        magn_dB   = raw_df.iloc[:, 1].values
        phase_rad = raw_df.iloc[:, 2].values
        phase_deg = np.degrees(phase_rad)

        # Build new filename and save
        new_name = f"{sample_name}_{freq_str}_{pwr}_{temperature}_{file_idx}.csv"
        out_path = organized_dir / new_name
        np.savetxt(out_path,
                   np.column_stack([freq_hz, magn_dB, phase_deg]),
                   delimiter=',', fmt='%.6f')

        metadata_rows.append({
            'power_str'   : pwr,
            'file_index'  : file_idx,
            'sweep_index' : entry['sweep_idx'],
            'unix_time'   : entry['unix_time'],
            'filename'    : new_name,
        })

# Save metadata CSV
meta_df = pd.DataFrame(metadata_rows)
meta_df.to_csv(organized_dir / "metadata.csv", index=False)

print(f"Organized files written to: {organized_dir}")
print(f"Total files: {len(metadata_rows)}")
print()
print(meta_df.groupby('power_str')['file_index'].count().rename('n_sweeps').to_string())
# Out:
# Organized files written to: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz
# Total files: 1000
#
# power_str
# -20dBm    250
# -40dBm    250
# -60dBm    250
# -80dBm    250

# %%
# Estimate sweep duration
#
# sweep_duration is the median time between consecutive sweeps of the same power.
# This is used later as the uniform time step for PSD analysis.

dt_samples = []
for pwr in all_powers:
    times = np.array([e['unix_time'] for e in power_groups[pwr]])
    if len(times) >= 2:
        dt_samples.extend(np.diff(times).tolist())

sweep_duration = float(np.median(dt_samples))
print(f"Estimated sweep duration : {sweep_duration:.3f} s  ({sweep_duration/60:.2f} min)")
print(f"Sampling frequency (1/Δt): {1/sweep_duration:.4f} Hz")
# Out:
# Estimated sweep duration : 179.000 s  (2.98 min)
# Sampling frequency (1/Δt): 0.0056 Hz

# %% [markdown]
# ## Section 2 — Time Trimming
#
# Plot the resonance dip frequency and dip |S21| for every sweep to identify when the
# conditions become stable.  Then set `trim_start_index` in the cell below the plot.

# %%
# ── Compute resonance dip from each organized CSV (fast — no fitting needed) ──

dip_data = {}   # power {'sweep_indices', 'dip_freqs_GHz', 'dip_mags_dB'}

for pwr in all_powers:
    n = len(power_groups[pwr])
    sweep_indices  = np.arange(n, dtype=int)
    dip_freqs_GHz  = np.full(n, np.nan)
    dip_mags_dB    = np.full(n, np.nan)

    for file_idx in range(n):
        fname = f"{sample_name}_{freq_str}_{pwr}_{temperature}_{file_idx}.csv"
        data  = np.loadtxt(organized_dir / fname, delimiter=',')
        freqs_Hz = data[:, 0]
        magn_dB  = data[:, 1]

        dip_idx = np.argmin(magn_dB)
        dip_freqs_GHz[file_idx] = freqs_Hz[dip_idx] / 1e9
        dip_mags_dB[file_idx]   = magn_dB[dip_idx]

    dip_data[pwr] = {
        'sweep_indices' : sweep_indices,
        'dip_freqs_GHz' : dip_freqs_GHz,
        'dip_mags_dB'   : dip_mags_dB,
    }
    print(f"  {pwr}: dip tracking done ({n} sweeps)")

print("Done.")
# Out:
#   -80dBm: dip tracking done (250 sweeps)
#   -60dBm: dip tracking done (250 sweeps)
#   -40dBm: dip tracking done (250 sweeps)
#   -20dBm: dip tracking done (250 sweeps)
# Done.

# %%
# Plot dip frequency and dip |S21| vs sweep index
#
# Top row  : dip frequency (GHz) — sensitive to temperature drift
# Bottom row: dip |S21| (dB)     — sensitive to coupling / loss changes

n_pwr = len(all_powers)
fig, axes = plt.subplots(2, n_pwr,
                         figsize=(max(5 * n_pwr, 8), 6),
                         sharex='col', sharey='row')
axes = np.atleast_2d(axes).reshape(2, n_pwr)   # ensure 2-D even for 1 power

for col, pwr in enumerate(all_powers):
    d  = dip_data[pwr]
    xi = d['sweep_indices']

    ax_top = axes[0, col]
    ax_bot = axes[1, col]

    ax_top.plot(xi, d['dip_freqs_GHz'], '.', ms=2, color='C0')
    ax_bot.plot(xi, d['dip_mags_dB'],  '.', ms=2, color='C1')

    ax_top.set_title(pwr, fontsize=11)
    ax_bot.set_xlabel("Sweep index (file_idx)")

axes[0, 0].set_ylabel("Dip frequency (GHz)")
axes[1, 0].set_ylabel("Dip |S21| (dB)")

fig.suptitle(
    f"{sample_name}  |  {res_label}_{freq_str}  |  {temperature}\n"
    "Resonance dip tracking — identify the stable-temperature onset",
    fontsize=11
)
fig.tight_layout()
plt.show()

print("\n→ Inspect the plot above, then set 'trim_start_index' in the next cell.")
# Out:
# → Inspect the plot above, then set 'trim_start_index' in the next cell.

# %%
# Set trim start index
#
# After viewing the dip plot above, set the file_idx from which all
# temperatures are stable.  Sweeps BELOW this index are discarded.
# The same index is applied to every power group.

trim_start_index = 166   # UPDATE!!! 

print(f"trim_start_index = {trim_start_index}")
for pwr in all_powers:
    n_total   = len(power_groups[pwr])
    n_kept    = n_total - trim_start_index
    n_discarded = trim_start_index
    print(f"  {pwr:>10s} : keep {n_kept}/{n_total}  "
          f"(discard first {n_discarded} sweeps)")
# Out:
# trim_start_index = 166
#       -80dBm : keep 84/250  (discard first 166 sweeps)
#       -60dBm : keep 84/250  (discard first 166 sweeps)
#       -40dBm : keep 84/250  (discard first 166 sweeps)
#       -20dBm : keep 84/250  (discard first 166 sweeps)

# %%
# Copy trimmed files to a new directory
#
# Trimmed files are re-indexed from 0 within each power group.
# A new metadata_trimmed.csv records the time of each trimmed sweep:
#   time_s = trimmed_file_index × sweep_duration   (relative to trim point)

trimmed_dir = target_dir / f"{res_label}_{freq_str}_trimmed"
trimmed_dir.mkdir(parents=True, exist_ok=True)

trimmed_meta_rows = []

for pwr in all_powers:
    trimmed_idx = 0
    for orig_idx, entry in enumerate(power_groups[pwr]):
        if orig_idx < trim_start_index:
            continue

        src_name = f"{sample_name}_{freq_str}_{pwr}_{temperature}_{orig_idx}.csv"
        dst_name = f"{sample_name}_{freq_str}_{pwr}_{temperature}_{trimmed_idx}.csv"
        shutil.copy2(organized_dir / src_name, trimmed_dir / dst_name)

        trimmed_meta_rows.append({
            'power_str'          : pwr,
            'trimmed_file_index' : trimmed_idx,
            'orig_file_index'    : orig_idx,
            'sweep_index'        : entry['sweep_idx'],
            'unix_time'          : entry['unix_time'],
            'time_s'             : trimmed_idx * sweep_duration,
            'filename'           : dst_name,
        })
        trimmed_idx += 1

trimmed_meta_df = pd.DataFrame(trimmed_meta_rows)
trimmed_meta_df.to_csv(trimmed_dir / "metadata_trimmed.csv", index=False)

print(f"Trimmed files saved to: {trimmed_dir}")
print()
print(trimmed_meta_df.groupby('power_str')['trimmed_file_index'].count()
      .rename('n_sweeps_kept').to_string())
# Out:
# Trimmed files saved to: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed
#
# power_str
# -20dBm    84
# -40dBm    84
# -60dBm    84
# -80dBm    84

# %% [markdown]
# ## Section 3 — DCM Circle Fit for Each Sweep
#
# For every trimmed CSV, call `fit_single_res` from *Fitting_Code_Lab_2.0* to extract
# Q, Qi, Qc, and fc using the DCM method.  Results are saved as
# `{sample_name}_{freq_str}_{power}_{temperature}_fit.csv` with columns:
#
# time_s; Q; Qi; Qc; fc_Hz
#
# Fit plots are saved under `{res_label}_{freq_str}_fit/fit_plots/`.
# Set `save_individual_fit_plots = False` to skip plot saving and speed up fitting.

# %%
# Fitting configuration

phi0 = 0.0    # phase offset (phi0) for Qc correction — adjust if your geometry requires it

# Set to False for large datasets to avoid saving thousands of individual fit PNGs
save_individual_fit_plots = False

# Output directories
fit_dir       = target_dir / f"{res_label}_{freq_str}_fit"
fit_plots_dir = fit_dir / "fit_plots"
fit_dir.mkdir(parents=True, exist_ok=True)
fit_plots_dir.mkdir(parents=True, exist_ok=True)

print(f"Fit results  → {fit_dir}")
print(f"Fit plots    → {fit_plots_dir}")
print(f"phi0         = {phi0}")
print(f"Save plots   : {save_individual_fit_plots}")
# Out:
# Fit results  → C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_fit
# Fit plots    → C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_fit\fit_plots
# phi0         = 0.0
# Save plots   : False

# %%
# Run fit_single_res on every trimmed file
#
# params returned by fit_single_res: [Q, Qc_mag, fc_Hz, phi]
# Qi is derived via the DCM formula:
#   Qcj = Qc_mag * exp(i*(phi + phi0))
#   1/Qi = 1/Q - Re(1/Qcj)

for pwr in all_powers:
    print(f"\n{'='*60}")
    print(f"Fitting power: {pwr}")
    print(f"{'='*60}")

    pwr_meta = trimmed_meta_df[trimmed_meta_df['power_str'] == pwr].reset_index(drop=True)
    N = len(pwr_meta)

    times  = np.full(N, np.nan)
    Q_arr  = np.full(N, np.nan)
    Qi_arr = np.full(N, np.nan)
    Qc_arr = np.full(N, np.nan)
    fc_arr = np.full(N, np.nan)

    for row in pwr_meta.itertuples(index=False):
        i   = row.trimmed_file_index
        t   = row.time_s
        csv = trimmed_dir / row.filename

        try:
            params, err, conf_int, fig = hf.fit_single_res(
                filename          = str(csv),
                preprocess_method = 'circle',
                save_dcm_plot     = save_individual_fit_plots,
                save_fit_dirs     = str(fit_plots_dir),
                manual_init       = None,
                plot_extra        = False,
            )
            plt.close('all')

            # Derive Qi from DCM formula 
            Q_val  = params[0]
            Qcj    = params[1] * np.exp(1j * (params[3] + phi0))
            Qi_val = float(np.real(1.0 / (1.0 / Q_val - np.real(1.0 / Qcj))))
            Qc_val = float(np.real(Qcj))
            fc_val = params[2]   # Hz

            if all(np.isfinite(v) for v in [Q_val, Qi_val, Qc_val, fc_val]) \
                    and Qi_val > 0 and Qc_val > 0:
                times[i]  = t
                Q_arr[i]  = Q_val
                Qi_arr[i] = Qi_val
                Qc_arr[i] = Qc_val
                fc_arr[i] = fc_val
            else:
                print(f"  [WARN] Unphysical fit at index {i:5d} (t={t:.1f}s) — NaN stored.")

        except Exception as exc:
            print(f"  [ERR]  Fit failed  at index {i:5d} (t={t:.1f}s): {exc}")

        # Progress print every 100 sweeps
        if (i + 1) % 100 == 0 or (i + 1) == N:
            n_done = np.sum(np.isfinite(Q_arr[:i+1]))
            print(f"  [{i+1:>5d}/{N}]  successful fits so far: {n_done}")

    # Save fit results
    fit_df = pd.DataFrame({'time_s': times, 'Q': Q_arr,
                           'Qi': Qi_arr,   'Qc': Qc_arr, 'fc_Hz': fc_arr})
    out_name = f"{sample_name}_{freq_str}_{pwr}_{temperature}_fit.csv"
    fit_df.to_csv(fit_dir / out_name, index=False)

    n_good = int(np.sum(np.isfinite(Q_arr)))
    print(f"\nFit results saved : {out_name}")
    print(f"Successful fits   : {n_good} / {N}")

print("\nAll powers fitted.")
# Out:
# ============================================================
# Fitting power: -80dBm
# ============================================================
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_0.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.688 kHz.
# Initial guess before curve fit shows that Q = 271070.
# Initial guess before curve fit shows that Qc = 630548.
# Initial guess before curve fit shows that phi = 0.0436 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 21.524 kHz.
# Initial guess after curve fit shows that Q = 260538.
# Initial guess after curve fit shows that Qc = 646248.
# Initial guess after curve fit shows that phi = -0.0030 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_1.csv
# Initial guess before curve fit shows that fc = 5.6079 GHz
# Initial guess before curve fit shows that linewidth = 96.503 kHz.
# Initial guess before curve fit shows that Q = 58111.
# Initial guess before curve fit shows that Qc = 107418.
# Initial guess before curve fit shows that phi = 0.1123 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 164.633 kHz.
# Initial guess after curve fit shows that Q = 34063.
# Initial guess after curve fit shows that Qc = 155231.
# Initial guess after curve fit shows that phi = -0.1566 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=51093.98824735337) = 0.0 < max(sigmas)
#   warn(errmsg)
# [WARNING] fitted fc is at sweep boundary → bad fit
# Warning: 1/Re[1/Qc] < 0. Calculating Qi anyway.
# WARNING:root:Delay could not be fit properly!
#   [WARN] Unphysical fit at index     1 (t=179.0s) — NaN stored.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_2.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 26.369 kHz.
# Initial guess before curve fit shows that Q = 212670.
# Initial guess before curve fit shows that Qc = 608854.
# Initial guess before curve fit shows that phi = -0.0734 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 27.753 kHz.
# Initial guess after curve fit shows that Q = 202063.
# Initial guess after curve fit shows that Qc = 604805.
# Initial guess after curve fit shows that phi = 0.0470 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_3.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 23.837 kHz.
# Initial guess before curve fit shows that Q = 235258.
# Initial guess before curve fit shows that Qc = 601375.
# Initial guess before curve fit shows that phi = -0.0440 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.830 kHz.
# Initial guess after curve fit shows that Q = 217103.
# Initial guess after curve fit shows that Qc = 578324.
# Initial guess after curve fit shows that phi = 0.0515 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_4.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 24.263 kHz.
# Initial guess before curve fit shows that Q = 231131.
# Initial guess before curve fit shows that Qc = 686855.
# Initial guess before curve fit shows that phi = -0.0858 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 29.797 kHz.
# Initial guess after curve fit shows that Q = 188200.
# Initial guess after curve fit shows that Qc = 586811.
# Initial guess after curve fit shows that phi = 0.0263 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_5.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 26.833 kHz.
# Initial guess before curve fit shows that Q = 208987.
# Initial guess before curve fit shows that Qc = 632928.
# Initial guess before curve fit shows that phi = 0.1375 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 33.491 kHz.
# Initial guess after curve fit shows that Q = 167444.
# Initial guess after curve fit shows that Qc = 547275.
# Initial guess after curve fit shows that phi = -0.0152 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_6.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 36.823 kHz.
# Initial guess before curve fit shows that Q = 152293.
# Initial guess before curve fit shows that Qc = 444133.
# Initial guess before curve fit shows that phi = -0.2087 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 37.423 kHz.
# Initial guess after curve fit shows that Q = 149851.
# Initial guess after curve fit shows that Qc = 448106.
# Initial guess after curve fit shows that phi = -0.0342 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_7.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 26.962 kHz.
# Initial guess before curve fit shows that Q = 207991.
# Initial guess before curve fit shows that Qc = 652889.
# Initial guess before curve fit shows that phi = 0.1117 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 28.433 kHz.
# Initial guess after curve fit shows that Q = 197229.
# Initial guess after curve fit shows that Qc = 605622.
# Initial guess after curve fit shows that phi = 0.0659 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_8.csv
#   [ERR]  Fit failed  at index     8 (t=1432.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_9.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 31.350 kHz.
# Initial guess before curve fit shows that Q = 178878.
# Initial guess before curve fit shows that Qc = 502568.
# Initial guess before curve fit shows that phi = 0.2218 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 30.745 kHz.
# Initial guess after curve fit shows that Q = 182396.
# Initial guess after curve fit shows that Qc = 498202.
# Initial guess after curve fit shows that phi = -0.0010 rad.
# WARNING:root:Delay could not be fit properly!
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_10.csv
# Initial guess before curve fit shows that fc = 5.6079 GHz
# Initial guess before curve fit shows that linewidth = 103.761 kHz.
# Initial guess before curve fit shows that Q = 54047.
# Initial guess before curve fit shows that Qc = 98677.
# Initial guess before curve fit shows that phi = 0.0936 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 94.149 kHz.
# Initial guess after curve fit shows that Q = 59564.
# Initial guess after curve fit shows that Qc = 148015.
# Initial guess after curve fit shows that phi = -1.0816 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=29782.002712125846) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=44612.74937443194) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Qc=74007.61044572963) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=182356.69879249512) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(phi=-3.141592653589793) = 0.0 < max(sigmas)
#   warn(errmsg)
# [WARNING] fitted fc is at sweep boundary → bad fit
# Warning: 1/Re[1/Qc] < 0. Calculating Qi anyway.
#   [WARN] Unphysical fit at index    10 (t=1790.0s) — NaN stored.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_11.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 23.931 kHz.
# Initial guess before curve fit shows that Q = 234337.
# Initial guess before curve fit shows that Qc = 590586.
# Initial guess before curve fit shows that phi = -0.2217 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.474 kHz.
# Initial guess after curve fit shows that Q = 220140.
# Initial guess after curve fit shows that Qc = 554916.
# Initial guess after curve fit shows that phi = -0.1585 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_12.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 21.575 kHz.
# Initial guess before curve fit shows that Q = 259927.
# Initial guess before curve fit shows that Qc = 653477.
# Initial guess before curve fit shows that phi = -0.1413 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.951 kHz.
# Initial guess after curve fit shows that Q = 216093.
# Initial guess after curve fit shows that Qc = 521935.
# Initial guess after curve fit shows that phi = 0.1059 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_13.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 59.494 kHz.
# Initial guess before curve fit shows that Q = 94259.
# Initial guess before curve fit shows that Qc = 146547.
# Initial guess before curve fit shows that phi = -0.5095 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 58.000 kHz.
# Initial guess after curve fit shows that Q = 96686.
# Initial guess after curve fit shows that Qc = 219820.
# Initial guess after curve fit shows that phi = -0.9353 rad.
# [WARNING] fitted fc is at sweep boundary → bad fit
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=48343.199546486016) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=92377.91760768383) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Qc=109909.94370914824) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Qc=329729.83112744475) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=5607844719.037151) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(w1=5607934574.647371) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=0.5112907632270537) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=1.8518621761335448) = 0.0 < max(sigmas)
#   warn(errmsg)
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_14.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.672 kHz.
# Initial guess before curve fit shows that Q = 285061.
# Initial guess before curve fit shows that Qc = 683375.
# Initial guess before curve fit shows that phi = -0.0119 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.337 kHz.
# Initial guess after curve fit shows that Q = 221327.
# Initial guess after curve fit shows that Qc = 542127.
# Initial guess after curve fit shows that phi = 0.1959 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_15.csv
#   [ERR]  Fit failed  at index    15 (t=2685.0s): Initial guess failed inside find_initial_guess(): Resonance is too close to edge of frequency span.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_16.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.314 kHz.
# Initial guess before curve fit shows that Q = 276059.
# Initial guess before curve fit shows that Qc = 653254.
# Initial guess before curve fit shows that phi = 0.0098 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 23.882 kHz.
# Initial guess after curve fit shows that Q = 234811.
# Initial guess after curve fit shows that Qc = 585186.
# Initial guess after curve fit shows that phi = -0.0367 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_17.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 72.195 kHz.
# Initial guess before curve fit shows that Q = 77676.
# Initial guess before curve fit shows that Qc = 109992.
# Initial guess before curve fit shows that phi = -0.2457 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 70.656 kHz.
# Initial guess after curve fit shows that Q = 79368.
# Initial guess after curve fit shows that Qc = 164988.
# Initial guess after curve fit shows that phi = -0.9161 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=39684.0513553705) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Qc=82493.85688972364) = 0.7481277730713934 < max(sigmas)
#   warn(errmsg)
# [WARNING] fitted fc is at sweep boundary → bad fit
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_18.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.344 kHz.
# Initial guess before curve fit shows that Q = 289896.
# Initial guess before curve fit shows that Qc = 721369.
# Initial guess before curve fit shows that phi = 0.0126 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 19.234 kHz.
# Initial guess after curve fit shows that Q = 291559.
# Initial guess after curve fit shows that Qc = 733822.
# Initial guess after curve fit shows that phi = -0.0578 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_19.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.236 kHz.
# Initial guess before curve fit shows that Q = 277124.
# Initial guess before curve fit shows that Qc = 635914.
# Initial guess before curve fit shows that phi = 0.2106 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 24.116 kHz.
# Initial guess after curve fit shows that Q = 232533.
# Initial guess after curve fit shows that Qc = 524919.
# Initial guess after curve fit shows that phi = -0.0094 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_20.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 24.560 kHz.
# Initial guess before curve fit shows that Q = 228329.
# Initial guess before curve fit shows that Qc = 510269.
# Initial guess before curve fit shows that phi = 0.0557 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 24.306 kHz.
# Initial guess after curve fit shows that Q = 230715.
# Initial guess after curve fit shows that Qc = 500463.
# Initial guess after curve fit shows that phi = 0.0413 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_21.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.700 kHz.
# Initial guess before curve fit shows that Q = 270908.
# Initial guess before curve fit shows that Qc = 624917.
# Initial guess before curve fit shows that phi = -0.1070 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 21.447 kHz.
# Initial guess after curve fit shows that Q = 261475.
# Initial guess after curve fit shows that Qc = 595533.
# Initial guess after curve fit shows that phi = 0.0238 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_22.csv
#   [ERR]  Fit failed  at index    22 (t=3938.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_23.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.627 kHz.
# Initial guess before curve fit shows that Q = 247836.
# Initial guess before curve fit shows that Qc = 594168.
# Initial guess before curve fit shows that phi = -0.1645 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 24.360 kHz.
# Initial guess after curve fit shows that Q = 230209.
# Initial guess after curve fit shows that Qc = 562251.
# Initial guess after curve fit shows that phi = -0.0295 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_24.csv
#   [ERR]  Fit failed  at index    24 (t=4296.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_25.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 21.764 kHz.
# Initial guess before curve fit shows that Q = 257668.
# Initial guess before curve fit shows that Qc = 606819.
# Initial guess before curve fit shows that phi = 0.1267 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 26.979 kHz.
# Initial guess after curve fit shows that Q = 207862.
# Initial guess after curve fit shows that Qc = 504343.
# Initial guess after curve fit shows that phi = -0.0348 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_26.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.944 kHz.
# Initial guess before curve fit shows that Q = 267760.
# Initial guess before curve fit shows that Qc = 627363.
# Initial guess before curve fit shows that phi = 0.0766 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 23.278 kHz.
# Initial guess after curve fit shows that Q = 240912.
# Initial guess after curve fit shows that Qc = 583256.
# Initial guess after curve fit shows that phi = 0.0516 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_27.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.799 kHz.
# Initial guess before curve fit shows that Q = 283245.
# Initial guess before curve fit shows that Qc = 643047.
# Initial guess before curve fit shows that phi = 0.0069 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 20.926 kHz.
# Initial guess after curve fit shows that Q = 267988.
# Initial guess after curve fit shows that Qc = 627703.
# Initial guess after curve fit shows that phi = -0.1878 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_28.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.996 kHz.
# Initial guess before curve fit shows that Q = 267093.
# Initial guess before curve fit shows that Qc = 639727.
# Initial guess before curve fit shows that phi = 0.0517 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 22.680 kHz.
# Initial guess after curve fit shows that Q = 247263.
# Initial guess after curve fit shows that Qc = 627940.
# Initial guess after curve fit shows that phi = 0.0773 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_29.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 18.547 kHz.
# Initial guess before curve fit shows that Q = 302351.
# Initial guess before curve fit shows that Qc = 718957.
# Initial guess before curve fit shows that phi = -0.4071 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 22.480 kHz.
# Initial guess after curve fit shows that Q = 249462.
# Initial guess after curve fit shows that Qc = 640993.
# Initial guess after curve fit shows that phi = -0.0264 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_30.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.041 kHz.
# Initial guess before curve fit shows that Q = 279817.
# Initial guess before curve fit shows that Qc = 674474.
# Initial guess before curve fit shows that phi = -0.0365 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 26.050 kHz.
# Initial guess after curve fit shows that Q = 215274.
# Initial guess after curve fit shows that Qc = 505592.
# Initial guess after curve fit shows that phi = 0.0116 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_31.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 24.328 kHz.
# Initial guess before curve fit shows that Q = 230514.
# Initial guess before curve fit shows that Qc = 616517.
# Initial guess before curve fit shows that phi = -0.0355 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 29.557 kHz.
# Initial guess after curve fit shows that Q = 189728.
# Initial guess after curve fit shows that Qc = 520269.
# Initial guess after curve fit shows that phi = -0.0810 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_32.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 31.301 kHz.
# Initial guess before curve fit shows that Q = 179159.
# Initial guess before curve fit shows that Qc = 489578.
# Initial guess before curve fit shows that phi = -0.1142 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 31.547 kHz.
# Initial guess after curve fit shows that Q = 177761.
# Initial guess after curve fit shows that Qc = 505890.
# Initial guess after curve fit shows that phi = -0.2163 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_33.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 25.735 kHz.
# Initial guess before curve fit shows that Q = 217911.
# Initial guess before curve fit shows that Qc = 590683.
# Initial guess before curve fit shows that phi = -0.2059 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 30.419 kHz.
# Initial guess after curve fit shows that Q = 184352.
# Initial guess after curve fit shows that Qc = 499071.
# Initial guess after curve fit shows that phi = 0.1207 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_34.csv
#   [ERR]  Fit failed  at index    34 (t=6086.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_35.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 33.292 kHz.
# Initial guess before curve fit shows that Q = 168442.
# Initial guess before curve fit shows that Qc = 434303.
# Initial guess before curve fit shows that phi = 0.0986 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 31.951 kHz.
# Initial guess after curve fit shows that Q = 175512.
# Initial guess after curve fit shows that Qc = 435071.
# Initial guess after curve fit shows that phi = 0.1541 rad.
# WARNING:root:Delay could not be fit properly!
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_36.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 112.104 kHz.
# Initial guess before curve fit shows that Q = 50023.
# Initial guess before curve fit shows that Qc = 98001.
# Initial guess before curve fit shows that phi = -0.2912 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 96.063 kHz.
# Initial guess after curve fit shows that Q = 58377.
# Initial guess after curve fit shows that Qc = 147001.
# Initial guess after curve fit shows that phi = -1.0219 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=29188.336078231685) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=138911.58569787556) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(w1=5607760791.200377) = 0.0 < max(sigmas)
#   warn(errmsg)
# [WARNING] fitted fc is at sweep boundary → bad fit
# Warning: 1/Re[1/Qc] < 0. Calculating Qi anyway.
#   [WARN] Unphysical fit at index    36 (t=6444.0s) — NaN stored.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_37.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.166 kHz.
# Initial guess before curve fit shows that Q = 252996.
# Initial guess before curve fit shows that Qc = 684467.
# Initial guess before curve fit shows that phi = -0.0374 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 23.557 kHz.
# Initial guess after curve fit shows that Q = 238059.
# Initial guess after curve fit shows that Qc = 683052.
# Initial guess after curve fit shows that phi = -0.0440 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_38.csv
#   [ERR]  Fit failed  at index    38 (t=6802.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_39.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.961 kHz.
# Initial guess before curve fit shows that Q = 244237.
# Initial guess before curve fit shows that Qc = 561251.
# Initial guess before curve fit shows that phi = 0.0880 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.618 kHz.
# Initial guess after curve fit shows that Q = 218899.
# Initial guess after curve fit shows that Qc = 513700.
# Initial guess after curve fit shows that phi = -0.0610 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_40.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.777 kHz.
# Initial guess before curve fit shows that Q = 269911.
# Initial guess before curve fit shows that Qc = 657364.
# Initial guess before curve fit shows that phi = 0.0590 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 21.521 kHz.
# Initial guess after curve fit shows that Q = 260576.
# Initial guess after curve fit shows that Qc = 646758.
# Initial guess after curve fit shows that phi = -0.0652 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_41.csv
# Initial guess before curve fit shows that fc = 5.6079 GHz
# Initial guess before curve fit shows that linewidth = 76.516 kHz.
# Initial guess before curve fit shows that Q = 73290.
# Initial guess before curve fit shows that Qc = 130170.
# Initial guess before curve fit shows that phi = -0.3037 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 89.457 kHz.
# Initial guess after curve fit shows that Q = 62689.
# Initial guess after curve fit shows that Qc = 164614.
# Initial guess after curve fit shows that phi = -0.9397 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=105019.77327167129) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=140331.7773153016) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=5607922164.803878) = 0.0 < max(sigmas)
#   warn(errmsg)
# [WARNING] fitted fc is at sweep boundary → bad fit
# Warning: 1/Re[1/Qc] < 0. Calculating Qi anyway.
#   [WARN] Unphysical fit at index    41 (t=7339.0s) — NaN stored.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_42.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 25.728 kHz.
# Initial guess before curve fit shows that Q = 217970.
# Initial guess before curve fit shows that Qc = 543550.
# Initial guess before curve fit shows that phi = 0.0198 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 27.732 kHz.
# Initial guess after curve fit shows that Q = 202213.
# Initial guess after curve fit shows that Qc = 496988.
# Initial guess after curve fit shows that phi = 0.1978 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_43.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.595 kHz.
# Initial guess before curve fit shows that Q = 248189.
# Initial guess before curve fit shows that Qc = 591357.
# Initial guess before curve fit shows that phi = -0.0562 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 21.221 kHz.
# Initial guess after curve fit shows that Q = 264263.
# Initial guess after curve fit shows that Qc = 668014.
# Initial guess after curve fit shows that phi = 0.2182 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_44.csv
#   [ERR]  Fit failed  at index    44 (t=7876.0s): Initial guess failed inside find_initial_guess(): No visible resonance dip found.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_45.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.398 kHz.
# Initial guess before curve fit shows that Q = 289095.
# Initial guess before curve fit shows that Qc = 636911.
# Initial guess before curve fit shows that phi = -0.0004 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 24.533 kHz.
# Initial guess after curve fit shows that Q = 228588.
# Initial guess after curve fit shows that Qc = 518578.
# Initial guess after curve fit shows that phi = -0.0401 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_46.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.639 kHz.
# Initial guess before curve fit shows that Q = 285548.
# Initial guess before curve fit shows that Qc = 650680.
# Initial guess before curve fit shows that phi = -0.2099 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 21.754 kHz.
# Initial guess after curve fit shows that Q = 257787.
# Initial guess after curve fit shows that Qc = 583407.
# Initial guess after curve fit shows that phi = -0.0955 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_47.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.943 kHz.
# Initial guess before curve fit shows that Q = 267772.
# Initial guess before curve fit shows that Qc = 585681.
# Initial guess before curve fit shows that phi = -0.0643 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 23.674 kHz.
# Initial guess after curve fit shows that Q = 236877.
# Initial guess after curve fit shows that Qc = 545315.
# Initial guess after curve fit shows that phi = -0.1753 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_48.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 20.125 kHz.
# Initial guess before curve fit shows that Q = 278644.
# Initial guess before curve fit shows that Qc = 631467.
# Initial guess before curve fit shows that phi = 0.1078 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.808 kHz.
# Initial guess after curve fit shows that Q = 217289.
# Initial guess after curve fit shows that Qc = 509623.
# Initial guess after curve fit shows that phi = 0.1110 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_49.csv
#   [ERR]  Fit failed  at index    49 (t=8771.0s): Initial guess failed inside find_initial_guess(): Resonance is too close to edge of frequency span.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_50.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 21.166 kHz.
# Initial guess before curve fit shows that Q = 264945.
# Initial guess before curve fit shows that Qc = 606975.
# Initial guess before curve fit shows that phi = -0.0751 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 23.696 kHz.
# Initial guess after curve fit shows that Q = 236660.
# Initial guess after curve fit shows that Qc = 537228.
# Initial guess after curve fit shows that phi = 0.0887 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_51.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.456 kHz.
# Initial guess before curve fit shows that Q = 249726.
# Initial guess before curve fit shows that Qc = 563794.
# Initial guess before curve fit shows that phi = -0.0644 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 27.165 kHz.
# Initial guess after curve fit shows that Q = 206434.
# Initial guess after curve fit shows that Qc = 454761.
# Initial guess after curve fit shows that phi = -0.0649 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_52.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.430 kHz.
# Initial guess before curve fit shows that Q = 288624.
# Initial guess before curve fit shows that Qc = 621613.
# Initial guess before curve fit shows that phi = 0.1700 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 20.822 kHz.
# Initial guess after curve fit shows that Q = 269317.
# Initial guess after curve fit shows that Qc = 564006.
# Initial guess after curve fit shows that phi = 0.1057 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_53.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 22.595 kHz.
# Initial guess before curve fit shows that Q = 248189.
# Initial guess before curve fit shows that Qc = 635712.
# Initial guess before curve fit shows that phi = -0.0297 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 24.424 kHz.
# Initial guess after curve fit shows that Q = 229604.
# Initial guess after curve fit shows that Qc = 638663.
# Initial guess after curve fit shows that phi = -0.0043 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_54.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 71.983 kHz.
# Initial guess before curve fit shows that Q = 77905.
# Initial guess before curve fit shows that Qc = 111329.
# Initial guess before curve fit shows that phi = -0.0895 rad.
# Initial guess after curve fit shows that fc = 5.6079 GHz
# Initial guess after curve fit shows that linewidth = 70.511 kHz.
# Initial guess after curve fit shows that Q = 79532.
# Initial guess after curve fit shows that Qc = 166993.
# Initial guess after curve fit shows that phi = -0.9291 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=39765.969407970144) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=71529.83809500566) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=88258.1667448309) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Qc=250489.3926229228) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=5607829704.959493) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=5607926503.593265) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=0.518998575513137) = 0.0 < max(sigmas)
#   warn(errmsg)
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:369: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=1.780339390013991) = 0.0 < max(sigmas)
#   warn(errmsg)
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_55.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 21.629 kHz.
# Initial guess before curve fit shows that Q = 259278.
# Initial guess before curve fit shows that Qc = 586189.
# Initial guess before curve fit shows that phi = 0.0078 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 26.077 kHz.
# Initial guess after curve fit shows that Q = 215046.
# Initial guess after curve fit shows that Qc = 487502.
# Initial guess after curve fit shows that phi = 0.0638 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_56.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 19.369 kHz.
# Initial guess before curve fit shows that Q = 289523.
# Initial guess before curve fit shows that Qc = 679428.
# Initial guess before curve fit shows that phi = -0.0871 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 25.049 kHz.
# Initial guess after curve fit shows that Q = 223879.
# Initial guess after curve fit shows that Qc = 512375.
# Initial guess after curve fit shows that phi = 0.1452 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_57.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 44.718 kHz.
# Initial guess before curve fit shows that Q = 125404.
# Initial guess before curve fit shows that Qc = 369898.
# Initial guess before curve fit shows that phi = -0.0178 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 40.417 kHz.
# Initial guess after curve fit shows that Q = 138750.
# Initial guess after curve fit shows that Qc = 400138.
# Initial guess after curve fit shows that phi = 0.6504 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-80dBm_15mK_58.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 87.584 kHz.
# Initial guess before curve fit shows that Q = 64028.
# Initial guess before curve fit shows that Qc = 90244.
# Initial guess before curve fit shows that phi = -0.3365 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 122.616 kHz.
# Initial guess after curve fit shows that Q = 45735.
# Initial guess after curve fit shows that Qc = 129114.
# Initial guess after curve fit shows that phi = -0.0915 rad.
# c:\Users\user\anaconda3\Lib\site-packages\lmfit\confidence.py:356: UserWarning: Bound reached with prob(Q=68602.10544902319) = 0.0 < max(sigmas)
#   warn(errmsg)
# ...
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723019.
# Initial guess before curve fit shows that phi = -0.0141 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.766 kHz.
# Initial guess after curve fit shows that Q = 407355.
# Initial guess after curve fit shows that Qc = 506885.
# Initial guess after curve fit shows that phi = 0.0153 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_64.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723299.
# Initial guess before curve fit shows that phi = -0.0148 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.774 kHz.
# Initial guess after curve fit shows that Q = 407146.
# Initial guess after curve fit shows that Qc = 506690.
# Initial guess after curve fit shows that phi = 0.0175 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_65.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723131.
# Initial guess before curve fit shows that phi = -0.0144 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.773 kHz.
# Initial guess after curve fit shows that Q = 407165.
# Initial guess after curve fit shows that Qc = 506618.
# Initial guess after curve fit shows that phi = 0.0173 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_66.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.801 kHz.
# Initial guess before curve fit shows that Q = 572165.
# Initial guess before curve fit shows that Qc = 714497.
# Initial guess before curve fit shows that phi = -0.0136 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.777 kHz.
# Initial guess after curve fit shows that Q = 407040.
# Initial guess after curve fit shows that Qc = 506502.
# Initial guess after curve fit shows that phi = 0.0158 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_67.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723186.
# Initial guess before curve fit shows that phi = -0.0140 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.767 kHz.
# Initial guess after curve fit shows that Q = 407325.
# Initial guess after curve fit shows that Qc = 506950.
# Initial guess after curve fit shows that phi = 0.0162 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_68.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723153.
# Initial guess before curve fit shows that phi = -0.0143 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.765 kHz.
# Initial guess after curve fit shows that Q = 407412.
# Initial guess after curve fit shows that Qc = 506908.
# Initial guess after curve fit shows that phi = 0.0161 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_69.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723259.
# Initial guess before curve fit shows that phi = -0.0137 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.771 kHz.
# Initial guess after curve fit shows that Q = 407208.
# Initial guess after curve fit shows that Qc = 506666.
# Initial guess after curve fit shows that phi = 0.0149 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_70.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.801 kHz.
# Initial guess before curve fit shows that Q = 572165.
# Initial guess before curve fit shows that Qc = 714485.
# Initial guess before curve fit shows that phi = -0.0142 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.770 kHz.
# Initial guess after curve fit shows that Q = 407245.
# Initial guess after curve fit shows that Qc = 506507.
# Initial guess after curve fit shows that phi = 0.0167 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_71.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.685 kHz.
# Initial guess before curve fit shows that Q = 579046.
# Initial guess before curve fit shows that Qc = 723319.
# Initial guess before curve fit shows that phi = -0.0136 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.780 kHz.
# Initial guess after curve fit shows that Q = 406956.
# Initial guess after curve fit shows that Qc = 506593.
# Initial guess after curve fit shows that phi = 0.0138 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_72.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712715.
# Initial guess before curve fit shows that phi = -0.0131 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.765 kHz.
# Initial guess after curve fit shows that Q = 407410.
# Initial guess after curve fit shows that Qc = 507032.
# Initial guess after curve fit shows that phi = 0.0109 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_73.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712674.
# Initial guess before curve fit shows that phi = -0.0130 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.764 kHz.
# Initial guess after curve fit shows that Q = 407427.
# Initial guess after curve fit shows that Qc = 506998.
# Initial guess after curve fit shows that phi = 0.0100 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_74.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.945 kHz.
# Initial guess before curve fit shows that Q = 563896.
# Initial guess before curve fit shows that Qc = 704298.
# Initial guess before curve fit shows that phi = -0.0128 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.763 kHz.
# Initial guess after curve fit shows that Q = 407446.
# Initial guess after curve fit shows that Qc = 506944.
# Initial guess after curve fit shows that phi = 0.0109 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_75.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712452.
# Initial guess before curve fit shows that phi = -0.0138 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.754 kHz.
# Initial guess after curve fit shows that Q = 407718.
# Initial guess after curve fit shows that Qc = 507187.
# Initial guess after curve fit shows that phi = 0.0128 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_76.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712689.
# Initial guess before curve fit shows that phi = -0.0129 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.757 kHz.
# Initial guess after curve fit shows that Q = 407632.
# Initial guess after curve fit shows that Qc = 507218.
# Initial guess after curve fit shows that phi = 0.0108 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_77.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.945 kHz.
# Initial guess before curve fit shows that Q = 563896.
# Initial guess before curve fit shows that Qc = 704379.
# Initial guess before curve fit shows that phi = -0.0141 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.772 kHz.
# Initial guess after curve fit shows that Q = 407206.
# Initial guess after curve fit shows that Qc = 506836.
# Initial guess after curve fit shows that phi = 0.0160 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_78.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 713024.
# Initial guess before curve fit shows that phi = -0.0135 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.766 kHz.
# Initial guess after curve fit shows that Q = 407380.
# Initial guess after curve fit shows that Qc = 507247.
# Initial guess after curve fit shows that phi = 0.0122 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_79.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712797.
# Initial guess before curve fit shows that phi = -0.0153 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.784 kHz.
# Initial guess after curve fit shows that Q = 406847.
# Initial guess after curve fit shows that Qc = 506424.
# Initial guess after curve fit shows that phi = 0.0161 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_80.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.945 kHz.
# Initial guess before curve fit shows that Q = 563896.
# Initial guess before curve fit shows that Qc = 704729.
# Initial guess before curve fit shows that phi = -0.0152 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.797 kHz.
# Initial guess after curve fit shows that Q = 406449.
# Initial guess after curve fit shows that Qc = 506007.
# Initial guess after curve fit shows that phi = 0.0161 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_81.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.945 kHz.
# Initial guess before curve fit shows that Q = 563896.
# Initial guess before curve fit shows that Qc = 704536.
# Initial guess before curve fit shows that phi = -0.0154 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.792 kHz.
# Initial guess after curve fit shows that Q = 406611.
# Initial guess after curve fit shows that Qc = 506202.
# Initial guess after curve fit shows that phi = 0.0170 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_82.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.829 kHz.
# Initial guess before curve fit shows that Q = 570544.
# Initial guess before curve fit shows that Qc = 712999.
# Initial guess before curve fit shows that phi = -0.0154 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.792 kHz.
# Initial guess after curve fit shows that Q = 406609.
# Initial guess after curve fit shows that Qc = 506111.
# Initial guess after curve fit shows that phi = 0.0156 rad.
# -------------
# fit_single_res: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_trimmed\QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_83.csv
# Initial guess before curve fit shows that fc = 5.6078 GHz
# Initial guess before curve fit shows that linewidth = 9.945 kHz.
# Initial guess before curve fit shows that Q = 563896.
# Initial guess before curve fit shows that Qc = 704610.
# Initial guess before curve fit shows that phi = -0.0150 rad.
# Initial guess after curve fit shows that fc = 5.6078 GHz
# Initial guess after curve fit shows that linewidth = 13.790 kHz.
# Initial guess after curve fit shows that Q = 406673.
# Initial guess after curve fit shows that Qc = 506287.
# Initial guess after curve fit shows that phi = 0.0164 rad.
#   [   84/84]  successful fits so far: 84
#
# Fit results saved : QSD_CPW_w6g3_03_5p608GHz_-20dBm_15mK_fit.csv
# Successful fits   : 84 / 84
#
# All powers fitted.

# %% [markdown]
# ## Section 4 — PSD Analysis
#
# Compute the Power Spectral Density of **fc**, **Q**, and **Qi** for each power
# using Welch's method.  The sampling frequency is `1 / sweep_duration`.

# %%
# Load fit results for all powers 

fit_results = {}   # cleaned DataFrame (NaN rows dropped)

for pwr in all_powers:
    fname = f"{sample_name}_{freq_str}_{pwr}_{temperature}_fit.csv"
    fpath = fit_dir / fname
    if not fpath.exists():
        print(f"[WARN] Fit results not found for {pwr}: {fpath}")
        continue

    df       = pd.read_csv(fpath)
    df_clean = df.dropna().reset_index(drop=True)
    fit_results[pwr] = df_clean

    n_total = len(df)
    n_clean = len(df_clean)
    print(f"  {pwr:>10s} : {n_clean:>5d} valid pts  "
          f"(dropped {n_total - n_clean} NaN rows)")

print()
print(f"Sampling frequency: {1/sweep_duration:.4f} Hz  "
      f"(sweep_duration = {sweep_duration:.3f} s)")
# Out:
#       -80dBm :    68 valid pts  (dropped 16 NaN rows)
#       -60dBm :    84 valid pts  (dropped 0 NaN rows)
#       -40dBm :    84 valid pts  (dropped 0 NaN rows)
#       -20dBm :    84 valid pts  (dropped 0 NaN rows)
#
# Sampling frequency: 0.0056 Hz  (sweep_duration = 179.000 s)

# %%
# Welch PSD for fc, Q, Qi 
#
# For fc: PSD of frequency fluctuations δf = fc - mean(fc)  [units: Hz²/Hz]
# For Q, Qi: PSD of fluctuations δQ = Q - mean(Q)           [units: 1/Hz]
#
# Welch parameters — adjust nperseg for frequency resolution vs noise trade-off
nperseg  = 60    # samples per Welch segment; must be ≤ min(n_sweeps) // 4
noverlap = None   # None → 50% overlap (scipy default)

quantities = [
    ('fc_Hz', r'$S_{\delta f_c}$  [Hz$^2$/Hz]',   'fc fluctuation δf (Hz)'),
    ('Q',     r'$S_{\delta Q}$  [Hz$^{-1}$]',     'Q fluctuation δQ'),
    ('Qi',    r'$S_{\delta Q_i}$  [Hz$^{-1}$]',   'Qi fluctuation δQi'),
]

fs = 1.0 / sweep_duration

fig, axes = plt.subplots(1, len(quantities),
                         figsize=(5 * len(quantities), 5),
                         sharey=False)

for ax, (qty_key, ylabel, desc) in zip(axes, quantities):
    for pwr in all_powers:
        if pwr not in fit_results:
            continue
        y = fit_results[pwr][qty_key].values.copy()
        y -= np.mean(y)   # remove DC offset (work with fluctuations)

        seg = min(nperseg, len(y) // 4)
        if seg < 8:
            print(f"  [WARN] Too few points for Welch ({pwr}, {qty_key}) — skipping.")
            continue

        freqs_psd, Pxx = sig.welch(y, fs=fs, nperseg=seg, noverlap=noverlap)

        mask = freqs_psd > 0   # skip DC bin on log axis
        ax.loglog(freqs_psd[mask], Pxx[mask], label=pwr, lw=1)

    ax.set_xlabel("Frequency (Hz)")
    ax.set_ylabel(ylabel)
    ax.set_title(desc, fontsize=10)
    ax.legend(fontsize=8, title="VNA power")
    ax.grid(True, which='both', alpha=0.3, ls='--')

fig.suptitle(
    f"PSD (Welch) — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}",
    fontsize=12
)
fig.tight_layout()

# Save PSD figure
psd_plot_path = fit_dir / f"PSD_{sample_name}_{freq_str}_{temperature}.png"
fig.savefig(psd_plot_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"PSD plot saved: {psd_plot_path}")
# Out:
# PSD plot saved: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_fit\PSD_QSD_CPW_w6g3_03_5p608GHz_15mK.png

# %%
# Optional: plot fit parameters vs time for a quick sanity check

fig, axes = plt.subplots(4, 1, figsize=(10, 10), sharex=True)

for pwr in all_powers:
    if pwr not in fit_results:
        continue
    df = fit_results[pwr]
    t  = df['time_s'].values / 60   # → minutes

    axes[0].plot(t, df['fc_Hz'].values / 1e9, '.-', ms=5, label=pwr)
    axes[1].plot(t, df['Q'].values,            '.-', ms=5, label=pwr)
    axes[2].plot(t, df['Qi'].values,           '.-', ms=5, label=pwr)
    axes[3].plot(t, df['Qc'].values,           '.-', ms=5, label=pwr)

labels = [r'$f_c$ (GHz)', r'$Q$', r'$Q_i$', r'$Q_c$']
for ax, lbl in zip(axes, labels):
    ax.set_ylabel(lbl)
    ax.legend(fontsize=8, ncol=2)
    ax.grid(True, alpha=0.3)

axes[-1].set_xlabel("Time (min)")
fig.suptitle(
    f"Fit parameters vs time — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}",
    fontsize=11
)
fig.tight_layout()

time_plot_path = fit_dir / f"fit_vs_time_{sample_name}_{freq_str}_{temperature}.png"
fig.savefig(time_plot_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Time-domain plot saved: {time_plot_path}")
# Out:
# Time-domain plot saved: C:\Users\user\Downloads\Line5_QSD_CPW_w6g3_03\Test_Time_Dependent_S21_organized\Resonator_2_5p608GHz_fit\fit_vs_time_QSD_CPW_w6g3_03_5p608GHz_15mK.png

# %% [markdown]
# ---
# ## Section 5 — Cross-Power Correlation Analysis
#
# Four complementary methods are applied to all pairwise combinations of powers:
#
# | Method | Domain | What it answers |
# |---|---|---|
# | **Coherence** γ²(f) | Spectral | At which fluctuation frequencies are two powers correlated? |
# | **Cross-PSD** S_xy(f) | Spectral | Magnitude & phase of the correlation vs frequency |
# | **Scatter + Pearson r** | Time | Are the fluctuations linearly correlated point-by-point? |
# | **Correlation matrix** | Time | Full pairwise r across all powers at a glance |
#
# All methods work on the **mean-subtracted fluctuations** δx = x − ⟨x⟩ of fc, Q, and Qi.
#
# **Note on alignment:** pairs of time series are restricted to indices where *both* signals
# have a valid (non-NaN) fit result.  If many fits failed, the effective sample size will
# be smaller than the total number of trimmed sweeps.

# %%
# ── Helper: build mean-subtracted, NaN-free aligned pairs ────────────────────
#
# Returns a dict:  (pwr_a, pwr_b) → {qty: (x, y)}  where x and y are
# 1-D arrays of equal length containing only indices valid in BOTH powers.

from itertools import combinations

quantities_corr = ['fc_Hz', 'Q', 'Qi']   # parameters to analyse
power_pairs     = list(combinations(all_powers, 2))

aligned = {}   # (pwr_a, pwr_b) → {qty: (x_array, y_array)}

for pwr_a, pwr_b in power_pairs:
    if pwr_a not in fit_results or pwr_b not in fit_results:
        print(f"[SKIP] Missing fit results for pair ({pwr_a}, {pwr_b})")
        continue

    df_a = fit_results[pwr_a]
    df_b = fit_results[pwr_b]

    # Align on the shorter index range, then keep only mutually valid rows
    n    = min(len(df_a), len(df_b))
    df_a = df_a.iloc[:n].reset_index(drop=True)
    df_b = df_b.iloc[:n].reset_index(drop=True)

    pair_data = {}
    for qty in quantities_corr:
        xa = df_a[qty].values.copy()
        xb = df_b[qty].values.copy()
        valid = np.isfinite(xa) & np.isfinite(xb)
        xa, xb = xa[valid] - xa[valid].mean(), xb[valid] - xb[valid].mean()
        pair_data[qty] = (xa, xb)

    aligned[(pwr_a, pwr_b)] = pair_data
    n_valid = np.isfinite(df_a['fc_Hz'].values) & np.isfinite(df_b['fc_Hz'].values)
    print(f"  Pair ({pwr_a}, {pwr_b}): {n_valid.sum()}/{n} valid points")

print(f"\nTotal pairs: {len(aligned)}")
# Out:
#   Pair (-80dBm, -60dBm): 68/68 valid points
#   Pair (-80dBm, -40dBm): 68/68 valid points
#   Pair (-80dBm, -20dBm): 68/68 valid points
#   Pair (-60dBm, -40dBm): 84/84 valid points
#   Pair (-60dBm, -20dBm): 84/84 valid points
#   Pair (-40dBm, -20dBm): 84/84 valid points
#
# Total pairs: 6

# %%
# ── Method 1: Coherence γ²(f) between all power pairs ────────────────────────
#
# γ²(f) = |S_xy(f)|² / (S_xx(f) · S_yy(f))
#   S_xx = auto-PSD of signal x  (Welch on x alone)
#   S_yy = auto-PSD of signal y  (Welch on y alone)
#   S_xy = cross-PSD of x and y  (scipy.signal.csd)
# scipy.signal.coherence computes all three internally.
#
# γ² ≈ 1  → fluctuations at that frequency share a common source
# γ² ≈ 0  → fluctuations are independent at that frequency

n_pairs = len(aligned)
n_qty   = len(quantities_corr)
qty_labels = {'fc_Hz': r'$f_c$', 'Q': r'$Q$', 'Qi': r'$Q_i$'}

fig, axes = plt.subplots(n_qty, n_pairs,
                         figsize=(4.5 * n_pairs, 3.5 * n_qty),
                         sharey='row', sharex='col')
axes = np.atleast_2d(axes).reshape(n_qty, n_pairs)

for col, (pwr_a, pwr_b) in enumerate(aligned.keys()):
    for row, qty in enumerate(quantities_corr):
        xa, xb = aligned[(pwr_a, pwr_b)][qty]
        seg    = min(nperseg, len(xa) // 4)

        f_coh, coh = sig.coherence(xa, xb, fs=fs, nperseg=seg)
        mask = f_coh > 0

        ax = axes[row, col]
        ax.semilogx(f_coh[mask], coh[mask], lw=1.2)
        ax.axhline(0.5, color='gray', lw=0.8, ls='--', label='γ²=0.5')
        ax.set_ylim(0, 1.05)
        ax.set_ylabel(f'Coherence  {qty_labels[qty]}')
        ax.grid(True, which='both', alpha=0.3, ls='--')
        if row == 0:
            ax.set_title(f'{pwr_a} vs {pwr_b}', fontsize=10)
        if row == n_qty - 1:
            ax.set_xlabel('Frequency (Hz)')

fig.suptitle(
    f'Coherence γ²(f) — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}',
    fontsize=11
)
fig.tight_layout()
fig.savefig(fit_dir / f'coherence_{sample_name}_{freq_str}_{temperature}.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Method 2: Cross-PSD magnitude and phase ───────────────────────────────────
#
# |S_xy(f)| : strength of the correlated fluctuation at each frequency
# ∠S_xy(f) : phase lag between the two signals
#   phase ≈  0° → in-phase (same noise source, same sign response)
#   phase ≈ 180° → anti-phase (same source, opposite sign response — e.g. TLS)

fig, axes = plt.subplots(n_qty * 2, n_pairs,
                         figsize=(4.5 * n_pairs, 3.0 * n_qty * 2),
                         sharex='col')
axes = np.atleast_2d(axes).reshape(n_qty * 2, n_pairs)

for col, (pwr_a, pwr_b) in enumerate(aligned.keys()):
    for q_idx, qty in enumerate(quantities_corr):
        xa, xb = aligned[(pwr_a, pwr_b)][qty]
        seg    = min(nperseg, len(xa) // 4)

        f_csd, Pxy = sig.csd(xa, xb, fs=fs, nperseg=seg)
        mask = f_csd > 0

        ax_mag = axes[q_idx * 2,     col]
        ax_ph  = axes[q_idx * 2 + 1, col]

        ax_mag.loglog(f_csd[mask], np.abs(Pxy[mask]), lw=1.5)
        ax_ph.semilogx(f_csd[mask], np.degrees(np.angle(Pxy[mask])),
                       '.', ms=10, alpha=0.6)
        ax_ph.axhline(  0, color='gray', lw=1.5, ls='--')
        ax_ph.axhline( 180, color='gray', lw=1.5, ls=':')
        ax_ph.axhline(-180, color='gray', lw=1.5, ls=':')
        ax_ph.set_ylim(-190, 190)
        ax_ph.set_yticks([-180, -90, 0, 90, 180])

        ax_mag.set_ylabel(f'|S_xy|  {qty_labels[qty]}')
        ax_ph.set_ylabel(f'∠S_xy (°)  {qty_labels[qty]}')
        ax_mag.grid(True, which='both', alpha=0.3, ls='--')
        ax_ph.grid(True, which='both', alpha=0.3, ls='--')

        if q_idx == 0:
            ax_mag.set_title(f'{pwr_a} vs {pwr_b}', fontsize=10)
        if q_idx == len(quantities_corr) - 1:
            ax_ph.set_xlabel('Frequency (Hz)')

fig.suptitle(
    f'Cross-PSD S_xy(f) — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}',
    fontsize=11
)
fig.tight_layout()
fig.savefig(fit_dir / f'cross_psd_{sample_name}_{freq_str}_{temperature}.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Method 3: Scatter plots + Pearson r (time domain) ────────────────────────
#
# Each point is one sweep.  x-axis = δ(quantity) at pwr_a,
#                           y-axis = δ(quantity) at pwr_b.
# Pearson r close to ±1 indicates strong linear correlation.

from scipy.stats import pearsonr

fig, axes = plt.subplots(n_qty, n_pairs,
                         figsize=(3.5 * n_pairs, 3.5 * n_qty))
axes = np.atleast_2d(axes).reshape(n_qty, n_pairs)

for col, (pwr_a, pwr_b) in enumerate(aligned.keys()):
    for row, qty in enumerate(quantities_corr):
        xa, xb = aligned[(pwr_a, pwr_b)][qty]
        r, p   = pearsonr(xa, xb)

        ax = axes[row, col]
        ax.scatter(xa, xb, s=5, alpha=0.3, rasterized=True)

        # Best-fit line
        m, b   = np.polyfit(xa, xb, 1)
        x_line = np.linspace(xa.min(), xa.max(), 200)
        ax.plot(x_line, m * x_line + b, 'r-', lw=1.2, label=f'r = {r:.3f}')
        ax.legend(fontsize=8, loc='upper left')

        ax.set_xlabel(f'δ{qty_labels[qty]}  ({pwr_a})', fontsize=8)
        ax.set_ylabel(f'δ{qty_labels[qty]}  ({pwr_b})', fontsize=8)
        ax.grid(True, alpha=0.3)
        if row == 0:
            ax.set_title(f'{pwr_a} vs {pwr_b}', fontsize=10)

fig.suptitle(
    f'Scatter & Pearson r — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}',
    fontsize=11
)
fig.tight_layout()
fig.savefig(fit_dir / f'scatter_pearson_{sample_name}_{freq_str}_{temperature}.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Method 4: Correlation matrix heatmap (all powers × all powers) ────────────
#
# For each quantity, build an N_powers × N_powers matrix of Pearson r values.
# Diagonal = 1 by definition.  Off-diagonal = r between that power pair.

from scipy.stats import pearsonr
import matplotlib.ticker as ticker

n_pwr = len(all_powers)
fig, axes = plt.subplots(1, n_qty, figsize=(4.5 * n_qty, 4.0))
axes = np.atleast_1d(axes)

for ax, qty in zip(axes, quantities_corr):
    r_matrix = np.full((n_pwr, n_pwr), np.nan)
    np.fill_diagonal(r_matrix, 1.0)

    for (pwr_a, pwr_b), pair_data in aligned.items():
        i = all_powers.index(pwr_a)
        j = all_powers.index(pwr_b)
        xa, xb    = pair_data[qty]
        r, _      = pearsonr(xa, xb)
        r_matrix[i, j] = r
        r_matrix[j, i] = r   # symmetric

    im = ax.imshow(r_matrix, vmin=-1, vmax=1, cmap='RdBu_r', aspect='equal')
    plt.colorbar(im, ax=ax, label='Pearson r')

    ax.set_xticks(range(n_pwr))
    ax.set_yticks(range(n_pwr))
    ax.set_xticklabels(all_powers, rotation=45, ha='right', fontsize=8)
    ax.set_yticklabels(all_powers, fontsize=8)
    ax.set_title(f'{qty_labels[qty]}  correlation', fontsize=11)

    # Annotate each cell with the r value
    for i in range(n_pwr):
        for j in range(n_pwr):
            if np.isfinite(r_matrix[i, j]):
                ax.text(j, i, f'{r_matrix[i, j]:.2f}',
                        ha='center', va='center', fontsize=8,
                        color='white' if abs(r_matrix[i, j]) > 0.6 else 'black')

fig.suptitle(
    f'Pearson r matrix — {sample_name}  |  {res_label}_{freq_str}  |  {temperature}',
    fontsize=11
)
fig.tight_layout()
fig.savefig(fit_dir / f'correlation_matrix_{sample_name}_{freq_str}_{temperature}.png',
            dpi=150, bbox_inches='tight')
plt.show()
